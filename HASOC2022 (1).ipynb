# %%
# !unzip "/content/finalzip.zip"inmu
# !unzip "/content/finalzip.zip" -d "/"

# %% [markdown]
# ### Importing Libraries and initializing stopwords and stemmer

# %%
import pandas as pd
import numpy as np
from glob import glob
import re
import json

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout


from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import stemmer as hindi_stemmer
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
english_stopwords = stopwords.words("english")
with open('final_stopwords.txt', encoding = 'utf-8') as f:
    hindi_stopwords = f.readlines()
    for i in range(len(hindi_stopwords)):
        hindi_stopwords[i] = re.sub('\n','',hindi_stopwords[i])
stopwords = english_stopwords + hindi_stopwords
english_stemmer = SnowballStemmer("english")

# %% [markdown]
# ## Reading Data

# %%
from glob import glob
train_directories = []
for i in glob("/content/finalzip/Hinglish/*/"):
    for j in glob(i+'*/'):
        train_directories.append(j)

train_directories
# Out:
# ['/content/finalzip/Hinglish/islamophobia/1534043530368552960/',
#  '/content/finalzip/Hinglish/islamophobia/1457992274353160192/',
#  '/content/finalzip/Hinglish/islamophobia/1427127023047114756/',
#  '/content/finalzip/Hinglish/islamophobia/1533742495426674688/',
#  '/content/finalzip/Hinglish/islamophobia/1427132613525852161/',
#  '/content/finalzip/Hinglish/islamophobia/1534698276540542976/',
#  '/content/finalzip/Hinglish/islamophobia/1427164007366942722/',
#  '/content/finalzip/Hinglish/islamophobia/1443896879461244936/',
#  '/content/finalzip/Hinglish/islamophobia/1460517156630663169/',
#  '/content/finalzip/Hinglish/islamophobia/1479780170265288706/',
#  '/content/finalzip/Hinglish/islamophobia/1457070488669376518/',
#  '/content/finalzip/Hinglish/islamophobia/1460523326384709637/',
#  '/content/finalzip/Hinglish/islamophobia/1534125155236073474/',
#  '/content/finalzip/Hinglish/islamophobia/1467510184142524421/',
#  '/content/finalzip/Hinglish/islamophobia/1486934002816540685/',
#  '/content/finalzip/Hinglish/islamophobia/1427169794726400005/',
#  '/content/finalzip/Hinglish/islamophobia/1533393257215840256/',
#  '/content/finalzip/Hinglish/islamophobia/1426975893583396869/',
#  '/content/finalzip/Hinglish/islamophobia/1460363642252189705/',
#  '/content/finalzip/Hinglish/islamophobia/1448906155850453018/',
#  '/content/finalzip/Hinglish/islamophobia/1464461678704308233/',
#  '/content/finalzip/Hinglish/islamophobia/1533414078798254080/',
#  '/content/finalzip/Hinglish/islamophobia/1533820267339866113/',
#  '/content/finalzip/Hinglish/islamophobia/1457771384143167500/',
#  '/content/finalzip/Hinglish/islamophobia/1530852232484204544/',
#  '/content/finalzip/Hinglish/CAA/1473117582139932676/',
#  '/content/finalzip/Hinglish/CAA/1462412497084825600/',
#  '/content/finalzip/Hinglish/CAA/1473123399765397506/',
#  '/content/finalzip/Hinglish/CAA/1471455877945180160/',
#  '/content/finalzip/Hinglish/CAA/1473357974542307330/',
#  '/content/finalzip/Hinglish/CAA/1473004497513320450/',
#  '/content/finalzip/Hinglish/taliban/1426951286243561482/',
#  '/content/finalzip/Hinglish/taliban/1427156888639217665/',
#  '/content/finalzip/Hinglish/taliban/1426954684464435203/',
#  '/content/finalzip/Hinglish/taliban/1427091167569715202/',
#  '/content/finalzip/Hinglish/taliban/1426966700927315972/',
#  '/content/finalzip/Hinglish/taliban/1427164365753446400/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1470356920556929025/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467689036991008770/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467687038140907522/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467712410534309889/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1335539265015517186/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467526803606540292/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467746524394262533/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1465319335849771012/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1468894517654740994/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467672078975258625/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467697523447848964/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1431810085500694530/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1470338865227460613/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467706058613288963/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467728527202021377/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1470064763950362629/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1465305031003893763/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467549830499078145/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467713383612829697/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1465339797640151044/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467702790948474880/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1467746096134852611/',
#  '/content/finalzip/Hinglish/temple_mosque_controversies/1432187242567458818/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1444185424394588162/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1445345549285134336/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1467128735782486016/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1457670233624305665/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1425091814177001481/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1438086487979954177/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1464964256365875200/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1467146580595658757/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1487753743185547267/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1478014196952408064/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1457717699690258441/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1457629029599625223/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1424709177906139138/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1442180719443210242/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1467109867160674312/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1467114029982175233/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1468564789399982080/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1445381930019696655/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1425111985922875402/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1444199065604943872/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1467136027844235270/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1468808780888489986/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1468821276630269954/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1462505338045747200/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1469852663063846914/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1438761952679907334/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1438709695166902279/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1447612071328112641/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1444166274003570694/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1444167179415392258/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1445378631958552576/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1468871205067243526/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1441383097119903752/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1425056016459206656/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1438719575944622083/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1444173510549524484/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1443986927938519041/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1464851061882118147/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1467095423022080007/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1445409787542482954/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1438803587950256129/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1425026689726246918/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1445331099333189638/',
#  '/content/finalzip/Hinglish/celebrity_controversies/1465002477548236808/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430764998083571712/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430934427471810560/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430707575603924992/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430522081704296459/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1429321225608728576/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430928842747781126/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430884839536750595/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430737249390383104/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430473995804037124/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430743559930404864/',
#  '/content/finalzip/Hinglish/historical_hindu_muslim/1430061294275629062/',
#  '/content/finalzip/Hinglish/cricket/1438820381075324932/',
#  '/content/finalzip/Hinglish/cricket/1438856249530064896/',
#  '/content/finalzip/Hinglish/cricket/1438824588159459336/',
#  '/content/finalzip/Hinglish/cricket/1242560043494621185/',
#  '/content/finalzip/Hinglish/cricket/1452844479124099082/',
#  '/content/finalzip/Hinglish/cricket/1438881267051814915/',
#  '/content/finalzip/Hinglish/cricket/1450073335849635840/',
#  '/content/finalzip/Hinglish/cricket/1452323201590124545/',
#  '/content/finalzip/Hinglish/cricket/1449434053422157825/',
#  '/content/finalzip/Hinglish/cricket/1452288430549909516/',
#  '/content/finalzip/Hinglish/kashmir/1465844898280579077/',
#  '/content/finalzip/Hinglish/kashmir/1465910508024832006/',
#  '/content/finalzip/Hinglish/kashmir/1432282015903199235/',
#  '/content/finalzip/Hinglish/common civil code/1467825731182891008/',
#  '/content/finalzip/Hinglish/common civil code/1460287308939206662/',
#  '/content/finalzip/Hinglish/hinduphobia/1456138648697462794/',
#  '/content/finalzip/Hinglish/hinduphobia/1433450998702379024/',
#  '/content/finalzip/Hinglish/hinduphobia/1467868537452568579/',
#  '/content/finalzip/Hinglish/hinduphobia/1474322685454864385/',
#  '/content/finalzip/Hinglish/hinduphobia/1457394927130841093/',
#  '/content/finalzip/Hinglish/hinduphobia/1467814659717668866/',
#  '/content/finalzip/Hinglish/hinduphobia/1448902089204289537/',
#  '/content/finalzip/Hinglish/hinduphobia/1475397374956564480/',
#  '/content/finalzip/Hinglish/hinduphobia/1467771110192140290/',
#  '/content/finalzip/Hinglish/hinduphobia/1214794148504457217/',
#  '/content/finalzip/Hinglish/hinduphobia/1467789851411943430/',
#  '/content/finalzip/Hinglish/hinduphobia/1436173144591536129/',
#  '/content/finalzip/Hinglish/hinduphobia/1467791638869135360/',
#  '/content/finalzip/Hinglish/hinduphobia/1433617324100120578/',
#  '/content/finalzip/Hinglish/hinduphobia/1448858962049314840/',
#  '/content/finalzip/Hinglish/covid/1477924528495886336/',
#  '/content/finalzip/Hinglish/covid/1479177165539188736/',
#  '/content/finalzip/Hinglish/covid/1470391992970616843/',
#  '/content/finalzip/Hinglish/covid/1475708977178632194/',
#  '/content/finalzip/Hinglish/covid/1464310918389587974/',
#  '/content/finalzip/Hinglish/russia_ukarain_conflict/1497403265750867971/',
#  '/content/finalzip/Hinglish/russia_ukarain_conflict/1497404257443753986/',
#  '/content/finalzip/Hinglish/namaz_on_public_space/1443581212514152451/',
#  '/content/finalzip/Hinglish/namaz_on_public_space/1443581537908187145/',
#  '/content/finalzip/Hinglish/namaz_on_public_space/1459864236423725056/',
#  '/content/finalzip/Hinglish/namaz_on_public_space/1468076489992065026/',
#  '/content/finalzip/Hinglish/namaz_on_public_space/1458858336443518984/',
#  '/content/finalzip/Hinglish/jew/1487696043815104515/',
#  '/content/finalzip/Hinglish/jew/1484674130184130564/',
#  '/content/finalzip/Hinglish/farmer_protest/1445338673185099779/',
#  '/content/finalzip/Hinglish/farmer_protest/1448887019292168192/',
#  '/content/finalzip/Hinglish/farmer_protest/1445236478015991811/',
#  '/content/finalzip/Hinglish/farmer_protest/1445281540280258562/',
#  '/content/finalzip/Hinglish/farmer_protest/1478711667454136320/',
#  '/content/finalzip/Hinglish/farmer_protest/1478660398710763522/',
#  '/content/finalzip/Hinglish/farmer_protest/1445336020958859269/',
#  '/content/finalzip/Hinglish/bullibai/1477924941156605952/',
#  '/content/finalzip/Hinglish/bullibai/1478629984524587008/',
#  '/content/finalzip/Hinglish/cast/1469616932437381120/',
#  '/content/finalzip/Hinglish/cast/1430916246644559876/',
#  '/content/finalzip/Hinglish/cast/1443202065723916289/',
#  '/content/finalzip/Hinglish/cast/1443243483301437445/']

# %%
data = []
for i in train_directories:
    with open(i+'data.json', encoding='utf-8') as f:
        data.append(json.load(f))
labels = []
for i in train_directories:
    with open(i+'binary_labels.json', encoding='utf-8') as f:
        labels.append(json.load(f))

# %%
def tr_flatten(d,l):
    flat_text = []
    flat_text.append({
        'tweet_id':d['tweet_id'],
        'text':d['tweet'],
        'label':l[d['tweet_id']]
    })

    for i in d['comments']:
            flat_text.append({
                'tweet_id':i['tweet_id'],
                'text':flat_text[0]['text'] +' '+i['tweet'], #flattening comments(appending one after the other)
                'label':l[i['tweet_id']]
            })
            if 'replies' in i.keys():
                for j in i['replies']:
                    flat_text.append({
                        'tweet_id':j['tweet_id'],
                        'text':flat_text[0]['text'] +' '+ i['tweet'] +' '+ j['tweet'], #flattening replies
                        'label':l[j['tweet_id']]
                    })
    return flat_text

def te_flatten(d):
    flat_text = []
    flat_text.append({
        'tweet_id':d['tweet_id'],
        'text':d['tweet'],
    })

    for i in d['comments']:
            flat_text.append({
                'tweet_id':i['tweet_id'],
                'text':flat_text[0]['text'] + i['tweet'],
            })
            if 'replies' in i.keys():
                for j in i['replies']:
                    flat_text.append({
                        'tweet_id':j['tweet_id'],
                        'text':flat_text[0]['text'] + i['tweet'] + j['tweet'],
                    })
    return flat_text

# %%
data_label = []
#for train
for i in range(len(labels)):
    for j in tr_flatten(data[i], labels[i]):
        data_label.append(j)
train_len = len(data_label)

# %%
df = pd.DataFrame(data_label, columns = data_label[0].keys(), index = None)

# %%
df.replace({"HOF":1,"NOT":0 }, inplace=True)

# %%
df.head()
# Out:
#               tweet_id                                               text  \
# 0  1534043530368552960  I believe that what Nupur Sharma ji said is ag...
# 1  1534078734642294784  I believe that what Nupur Sharma ji said is ag...
# 2  1534080292377460736  I believe that what Nupur Sharma ji said is ag...
# 3  1534086557283635200  I believe that what Nupur Sharma ji said is ag...
# 4  1534090171611635713  I believe that what Nupur Sharma ji said is ag...
#
#    label
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1

# %%
df['label'].value_counts()
# Out:
# 1    2524
# 0    2390
# Name: label, dtype: int64

# %%
tweets = df.text
y = df.label

# %% [markdown]
# ## Preprocessing and featuring the raw text

# %% [markdown]
# <p>This is a preprocessing function and the regex will match with anything that is not English, Hindi and Emoji.</p>
# <p>The preprocessing steps are as followed:</p>
# <ul>
#     <li>Remove Handles</li>
#     <li>Remove URLs</li>
#     <li>Remove anything that is not English, Hindi and Emoji</li>
#     <li>Remove RT which appears in retweets</li>
#     <li>Remove Abundant Newlines</li>
#     <li>Remove Abundant whitespaces</li>
#     <li>Remove Stopwords</li>
#     <li>Stem English text</li>
#     <li>Stem Hindi text</li>
# </ul>

# %%
regex_for_english_hindi_emojis="[^a-zA-Z#\U0001F300-\U0001F5FF'|'\U0001F600-\U0001F64F'|'\U0001F680-\U0001F6FF'|'\u2600-\u26FF\u2700-\u27BF\u0900-\u097F]"
def clean_tweet(tweet):
    tweet = re.sub(r"@[A-Za-z0-9]+",' ', tweet)
    tweet = re.sub(r"https?://[A-Za-z0-9./]+",' ', tweet)
    tweet = re.sub(regex_for_english_hindi_emojis,' ', tweet)
    tweet = re.sub("RT ", " ", tweet)
    tweet = re.sub("\n", " ", tweet)
    tweet = re.sub(r" +", " ", tweet)
    tokens = []
    for token in tweet.split():
        if token not in stopwords:
            token = english_stemmer.stem(token)
            token = hindi_stemmer.hi_stem(token)
            tokens.append(token)
    return " ".join(tokens)

# %%
cleaned_tweets = [clean_tweet(tweet) for tweet in tweets]

# %% [markdown]
# <p>Using TF-IDF for featuring the text. The vectorizer will only consider vocab terms that appear in more than 5 documents.</p>
# <p>To learn more about TF-IDF you can check <a href = "https://towardsdatascience.com/tf-term-frequency-idf-inverse-document-frequency-from-scratch-in-python-6c2b61b78558">here</a> and <a href = "https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html">here</a>.</p>

# %%
vectorizer = TfidfVectorizer(min_df = 5)
X = vectorizer.fit_transform(cleaned_tweets)
X = X.todense()

# %% [markdown]
# ## Training and evaluating model

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# <p>Training the Logistic Regression classifier provided by Scikit-Learn library.</p>
# <p>To learn more about Logistic Regression classifier you can check <a href = "https://www.youtube.com/watch?v=yIYKR4sgzI8">here</a> and <a href = "https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html">here</a>.</p>

# %%
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# <p>Predicting and priting classification metrics for validation set.</p>

# %%
y_pred = classifier.predict(X_val)

# %%
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.70       719
#            1       0.71      0.70      0.71       756
#
#     accuracy                           0.70      1475
#    macro avg       0.70      0.70      0.70      1475
# weighted avg       0.70      0.70      0.70      1475

# %%
# !pip install lazypredict

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0,predictions=True)
models,predictions = clf.fit(X_train, X_val, y_train, y_val)
models
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)
# 100%|██████████| 29/29 [08:34<00:00, 17.74s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.72               0.72     0.72      0.72
# ExtraTreesClassifier               0.71               0.71     0.71      0.71
# SVC                                0.71               0.71     0.71      0.71
# NuSVC                              0.71               0.70     0.70      0.71
# XGBClassifier                      0.70               0.70     0.70      0.70
# BaggingClassifier                  0.70               0.70     0.70      0.70
# NearestCentroid                    0.69               0.69     0.69      0.69
# LGBMClassifier                     0.69               0.69     0.69      0.69
# BernoulliNB                        0.69               0.69     0.69      0.69
# LogisticRegression                 0.68               0.68     0.68      0.68
# Perceptron                         0.67               0.67     0.67      0.67
# PassiveAggressiveClassifier        0.67               0.67     0.67      0.67
# ExtraTreeClassifier                0.67               0.67     0.67      0.67
# CalibratedClassifierCV             0.67               0.67     0.67      0.67
# SGDClassifier                      0.66               0.66     0.66      0.66
# DecisionTreeClassifier             0.66               0.66     0.66      0.66
# LinearSVC                          0.66               0.66     0.66      0.66
# GaussianNB                         0.65               0.65     0.65      0.63
# KNeighborsClassifier               0.65               0.65     0.65      0.64
# AdaBoostClassifier                 0.65               0.65     0.65      0.65
# RidgeClassifierCV                  0.64               0.64     0.64      0.64
# RidgeClassifier                    0.63               0.63     0.63      0.63
# QuadraticDiscriminantAnalysis      0.61               0.61     0.61      0.59
# LinearDiscriminantAnalysis         0.57               0.57     0.57      0.57
# LabelSpreading                     0.51               0.52     0.52      0.38
# LabelPropagation                   0.51               0.52     0.52      0.38
# DummyClassifier                    0.51               0.51     0.51      0.51
#
#                                Time Taken
# Model
# RandomForestClassifier               7.41
# ExtraTreesClassifier                13.24
# SVC                                 81.49
# NuSVC                               85.79
# XGBClassifier                       36.79
# BaggingClassifier                   19.30
# NearestCentroid                      0.67
# LGBMClassifier                       5.30
# BernoulliNB                          0.74
# LogisticRegression                   2.38
# Perceptron                           1.70
# PassiveAggressiveClassifier          4.05
# ExtraTreeClassifier                  0.73
# CalibratedClassifierCV              97.59
# SGDClassifier                        1.57
# DecisionTreeClassifier               5.47
# LinearSVC                           20.83
# GaussianNB                           0.81
# KNeighborsClassifier                32.14
# AdaBoostClassifier                  10.85
# RidgeClassifierCV                   28.36
# RidgeClassifier                      2.56
# QuadraticDiscriminantAnalysis       15.58
# LinearDiscriminantAnalysis          30.00
# LabelSpreading                       3.69
# LabelPropagation                     3.45
# DummyClassifier                      0.58

# %%
import plotly.express as px
fig = px.bar(models, x=models["F1 Score"], y=models.index,color=models["Accuracy"],
            title='Top Model Accuracy' ,width=800, height=900, template = 'plotly_white')
fig.update_layout(showlegend=False, font_size=18,yaxis={'categoryorder':'total ascending'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="78baeecc-9f6d-4aea-b3b8-25ced5c190b2" class="plotly-graph-div" style="height:900px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78baeecc-9f6d-4aea-b3b8-25ced5c190b2")) {                    Plotly.newPlot(                        "78baeecc-9f6d-4aea-b3b8-25ced5c190b2",                        [{"alignmentgroup":"True","hovertemplate":"F1 Score=%{x}<br>Model=%{y}<br>Accuracy=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.7159322033898305,0.7125423728813559,0.7071186440677966,0.7057627118644068,0.6996610169491525,0.6955932203389831,0.6935593220338983,0.6908474576271186,0.6874576271186441,0.6752542372881356,0.6738983050847458,0.6711864406779661,0.6705084745762712,0.6705084745762712,0.6610169491525424,0.6589830508474577,0.656271186440678,0.6467796610169492,0.6461016949152543,0.6488135593220339,0.6359322033898305,0.6264406779661017,0.6128813559322034,0.5735593220338983,0.5077966101694915,0.5077966101694915,0.5145762711864407],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.7159413431921043,0.7124876704907689,0.7062886108967208,0.7054064214813344,0.6996751052512948,0.6955428487609496,0.6928865904110189,0.6908738995845343,0.6851217122715813,0.6752485614318094,0.67378124637804,0.671047512341287,0.6705190818273656,0.6694216365962631,0.6607328240938051,0.6588160341058776,0.6562379814423605,0.6349706805662928,0.640363339843761,0.6487941890044404,0.6359589903026747,0.6264973522581458,0.5930091718284086,0.5736204928358092,0.3771867906756499,0.3771867906756499,0.5146365335653221],"xaxis":"x","y":["RandomForestClassifier","ExtraTreesClassifier","SVC","NuSVC","XGBClassifier","BaggingClassifier","NearestCentroid","LGBMClassifier","BernoulliNB","LogisticRegression","Perceptron","PassiveAggressiveClassifier","ExtraTreeClassifier","CalibratedClassifierCV","SGDClassifier","DecisionTreeClassifier","LinearSVC","GaussianNB","KNeighborsClassifier","AdaBoostClassifier","RidgeClassifierCV","RidgeClassifier","QuadraticDiscriminantAnalysis","LinearDiscriminantAnalysis","LabelSpreading","LabelPropagation","DummyClassifier"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatm ...

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import NearestCentroid
from lightgbm import LGBMClassifier
# ligthgbm = LGBMClassifier( random_state=2021)
# import xgboost
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import VotingClassifier

# lda = LinearDiscriminantAnalysis()
# rcCV = RidgeClassifierCV()
# rc = RidgeClassifier()
# ccCV = CalibratedClassifierCV()
# xgb = xgboost()
import xgboost
xgb = xgboost.XGBClassifier()
lr = LogisticRegression()
nc = NearestCentroid()
lgb = LGBMClassifier()

Classifier=VotingClassifier(estimators=[('xgb',xgb), ('lr',lr),('nc',nc),('lgb',lgb)],voting='hard')
Classifier.fit(X_train,y_train)
y_pred = Classifier.predict(X_val)

# %%
print('Voting Model accuracy score: {0:0.4f}'.format(accuracy_score(y_val, y_pred)))
print("f1 score:",f1_score(y_val,y_pred))
print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
# Voting Model accuracy score: 0.6956
# f1 score: 0.675343456254519
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71       719
#            1       0.74      0.62      0.68       756
#
#     accuracy                           0.70      1475
#    macro avg       0.70      0.70      0.69      1475
# weighted avg       0.70      0.70      0.69      1475
#
# [[559 160]
#  [289 467]]

# %%
# BAGGING ENSEMBLE TECHNIQUE
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
Classifier = BaggingClassifier(LogisticRegression(), n_estimators=50, max_samples=100, bootstrap=True, n_jobs=-1)
Classifier.fit(X_train,y_train)
y_pred = Classifier.predict(X_val)

print('Bagging Ensemble Technique accuracy score: {0:0.4f}'.format(accuracy_score(y_val, y_pred)))
print("f1 score:",f1_score(y_val,y_pred))
print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
# Bagging Ensemble Technique accuracy score: 0.6617
# f1 score: 0.701376421304608
#               precision    recall  f1-score   support
#
#            0       0.70      0.54      0.61       719
#            1       0.64      0.78      0.70       756
#
#     accuracy                           0.66      1475
#    macro avg       0.67      0.66      0.66      1475
# weighted avg       0.67      0.66      0.66      1475
#
# [[390 329]
#  [170 586]]

# %%
# RANDOM FOREST ENSEMBLE TECHNIQUE
from sklearn.ensemble import RandomForestClassifier
Classifier = RandomForestClassifier(n_estimators=50, max_leaf_nodes=13, n_jobs=-1)
Classifier.fit(X_train,y_train)
y_pred = Classifier.predict(X_val)

print('Random Forest accuracy score: {0:0.4f}'.format(accuracy_score(y_val, y_pred)))
print("f1 score:",f1_score(y_val,y_pred))
print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
# Random Forest accuracy score: 0.6658
# f1 score: 0.623951182303585
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.70       719
#            1       0.74      0.54      0.62       756
#
#     accuracy                           0.67      1475
#    macro avg       0.68      0.67      0.66      1475
# weighted avg       0.68      0.67      0.66      1475
#
# [[573 146]
#  [347 409]]

# %%
# ADABOOST ENSEMBLE TECHNIQUE
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
Classifier = AdaBoostClassifier(DecisionTreeClassifier(min_samples_split=10,max_depth=3),n_estimators=50,learning_rate=0.6)
Classifier.fit(X_train,y_train)
y_pred = Classifier.predict(X_val)

print('Adaboost accuracy score: {0:0.4f}'.format(accuracy_score(y_val, y_pred)))
print("f1 score:",f1_score(y_val,y_pred))
print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
# Adaboost accuracy score: 0.6637
# f1 score: 0.6648648648648648
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.66       719
#            1       0.68      0.65      0.66       756
#
#     accuracy                           0.66      1475
#    macro avg       0.66      0.66      0.66      1475
# weighted avg       0.66      0.66      0.66      1475
#
# [[487 232]
#  [264 492]]

# %%
# GRADIENT BOOSTING ENSEMBLE TECHNIQUE
from sklearn.ensemble import GradientBoostingClassifier
Classifier = GradientBoostingClassifier(max_depth=7, n_estimators=30, learning_rate=0.01)
Classifier.fit(X_train,y_train)
y_pred = Classifier.predict(X_val)

print('Gradient boosting accuracy score: {0:0.4f}'.format(accuracy_score(y_val, y_pred)))
print("f1 score:",f1_score(y_val,y_pred))
print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
# Gradient boosting accuracy score: 0.6359
# f1 score: 0.5587510271158586
#               precision    recall  f1-score   support
#
#            0       0.59      0.83      0.69       719
#            1       0.74      0.45      0.56       756
#
#     accuracy                           0.64      1475
#    macro avg       0.66      0.64      0.62      1475
# weighted avg       0.67      0.64      0.62      1475
#
# [[598 121]
#  [416 340]]

# %%
# XGBOOST ENSEMBLE TECHNIQUE
from sklearn.ensemble import GradientBoostingClassifier
import xgboost
Classifier = xgboost.XGBClassifier()
Classifier.fit(X_train,y_train)
y_pred = Classifier.predict(X_val)
print('Extreme Gradient boosting accuracy score: {0:0.4f}'.format(accuracy_score(y_val, y_pred)))
print("f1 score:",f1_score(y_val,y_pred))
print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
# Extreme Gradient boosting accuracy score: 0.6997
# f1 score: 0.7064280980781974
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69       719
#            1       0.71      0.71      0.71       756
#
#     accuracy                           0.70      1475
#    macro avg       0.70      0.70      0.70      1475
# weighted avg       0.70      0.70      0.70      1475
#
# [[499 220]
#  [223 533]]

# %% [markdown]
# **NEURAL NETWORK**

# %%
le = LabelEncoder() #label encoding labels for training Dense Neural Network
y_train = le.fit_transform(y_train)
y_val = le.transform(y_val)

# %%
model = Sequential(
    [
        Dense(64, activation="relu"),
        Dense(32, activation="relu"),
        Dense(1, activation="sigmoid"),
    ]
)
model.compile('adam', loss='binary_crossentropy', metrics = ['accuracy']) #compiling a neural network with 3 layers for classification

# %%
model.fit(X_train, y_train, epochs = 5, batch_size = 32)
# Out:
# Epoch 1/5
# 108/108 [==============================] - 1s 4ms/step - loss: 0.6336 - accuracy: 0.6583
# Epoch 2/5
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5096 - accuracy: 0.7557
# Epoch 3/5
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4197 - accuracy: 0.8075
# Epoch 4/5
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3473 - accuracy: 0.8479
# Epoch 5/5
# 108/108 [==============================] - 0s 4ms/step - loss: 0.2839 - accuracy: 0.8822

# %%
y_pred = model.predict(X_val)
y_pred = (y_pred > 0.5).astype('int64')
y_pred = y_pred.reshape(len(y_pred))

# %%
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.74      0.71       719
#            1       0.73      0.67      0.70       756
#
#     accuracy                           0.70      1475
#    macro avg       0.70      0.70      0.70      1475
# weighted avg       0.70      0.70      0.70      1475

# %%
from glob import glob
test_directories = []
for i in glob("/content/finalzip/Hinglish_test/*/"):
    for j in glob(i+'*/'):
        test_directories.append(j)

# %%
test_directories
# Out:
# ['/content/finalzip/Hinglish_test/islamophobia/1442176510224261120/',
#  '/content/finalzip/Hinglish_test/islamophobia/1533444368690032641/',
#  '/content/finalzip/Hinglish_test/temple_mosque_controversies/1467712410534309889/',
#  '/content/finalzip/Hinglish_test/temple_mosque_controversies/1467731786151170049/',
#  '/content/finalzip/Hinglish_test/celebrity_controversies/1438882238087659525/',
#  '/content/finalzip/Hinglish_test/celebrity_controversies/1425321569350414343/',
#  '/content/finalzip/Hinglish_test/historical_hindu_muslim/1445435933214617602/',
#  '/content/finalzip/Hinglish_test/ozil/1438762071835951104/',
#  '/content/finalzip/Hinglish_test/hinduphobia/1467895004223791105/',
#  '/content/finalzip/Hinglish_test/hinduphobia/1470652707824291843/',
#  '/content/finalzip/Hinglish_test/hinduphobia/1445930336039358469/',
#  '/content/finalzip/Hinglish_test/russia_ukarain_conflict/1497413697056215043/',
#  '/content/finalzip/Hinglish_test/farmer_protest/1480518248076509184/']

# %%
test_data = []
for i in test_directories:
    with open(i+'data.json', encoding='utf-8') as f:
        data.append(json.load(f))

# %%
test_tweetid_data = []
#for test
for i in range(len(labels), len(data)):
    for j in te_flatten(data[i]):
        test_tweetid_data.append(j)

# %%
test_tweetid_data
# Out:
# [{'tweet_id': '1442176510224261120',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K'},
#  {'tweet_id': '1442176690235461647',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks 😂😂 मान जा !!'},
#  {'tweet_id': '1442341201479233543',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks 😂😂 मान जा !!@KamalKesari1 @TheZaiduLeaks Sarcasm tha bhai iski purani tweets dekhle pta chal jayega kon hai phir follow krlio okk bhai'},
#  {'tweet_id': '1442176841322618880',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks No this is new grievyard in making..😂😂😂😂'},
#  {'tweet_id': '1442177683899568133',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh mann!! It's the new graveyard meant for u people....."},
#  {'tweet_id': '1442198857278844934',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh mann!! It's the new graveyard meant for u people.....@RashidK28056042 @TheZaiduLeaks its a timepass sarcasm. and he is pakistani only. i have strong proofs of that. huh. chale aye sarcasm sarcasm karke."},
#  {'tweet_id': '1442183360713953284',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh mann!! It's the new graveyard meant for u people.....@RashidK28056042 @TheZaiduLeaks Hey idiot,\nThis is sarcasm. He is Indian."},
#  {'tweet_id': '1442177876720189440',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Now waiting for print india to post this tweet in their news'},
#  {'tweet_id': '1442206853589467137',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Now waiting for print india to post this tweet in their news@SalamiS62936679 @TheZaiduLeaks 😂😂'},
#  {'tweet_id': '1442269798704967681',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Now waiting for print india to post this tweet in their news@SalamiS62936679 @TheZaiduLeaks 🤣 😂 🤣 😂'},
#  {'tweet_id': '1442320695115927557',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Now waiting for print india to post this tweet in their news@SalamiS62936679 @TheZaiduLeaks 😂😅'},
#  {'tweet_id': '1442379323558617094',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Now waiting for print india to post this tweet in their news@SalamiS62936679 @TheZaiduLeaks 😂'},
#  {'tweet_id': '1442667363774517250',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Now waiting for print india to post this tweet in their news@SalamiS62936679 @TheZaiduLeaks Print is somewhat better. The wire will take it seriously.'},
#  {'tweet_id': '1442178416002801670',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You could’ve added a few more zeroes ! 😂'},
#  {'tweet_id': '1442489267863769088',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You could’ve added a few more zeroes ! 😂@ColSB23 @TheZaiduLeaks That's the ammount they borrowed from the world n not paying"},
#  {'tweet_id': '1442178482872586244',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Correct the count: 200,000,0000,0046'},
#  {'tweet_id': '1442182525309227013',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Correct the count: 200,000,0000,0046@TheNameIsVeer @TheZaiduLeaks Bhai please rajyasabha wale bhi jod de'},
#  {'tweet_id': '1442178618063347714',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Itne buslim kaun gola par hain??'},
#  {'tweet_id': '1442180105116078085',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh no! He’s started to construct a block of apartments over the graves! How devious…'},
#  {'tweet_id': '1442320048069115904',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh no! He’s started to construct a block of apartments over the graves! How devious…@poojajoshi1979 @TheZaiduLeaks Abe pagal wo jhut bol raha hai modi ji parliament bulding ke construction site par gye hai'},
#  {'tweet_id': '1442549374731513863',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh no! He’s started to construct a block of apartments over the graves! How devious…@poojajoshi1979 @TheZaiduLeaks Looks like Drisyam 3 😋😋😋'},
#  {'tweet_id': '1442388348442607617',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh no! He’s started to construct a block of apartments over the graves! How devious…@poojajoshi1979 @TheZaiduLeaks Are you educated or a illetrate'},
#  {'tweet_id': '1442680371372445702',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Oh no! He’s started to construct a block of apartments over the graves! How devious…@poojajoshi1979 @TheZaiduLeaks Nahi nahi Modi ji yeh bhi bata rahe hain ki Kashmir khaali nahi kiya to hum apna Parliament Islamabad laa rahe hain....aur hamare parliament ki jagah in pokistaniyon ki laashon pe banegi...'},
#  {'tweet_id': '1442186437873442816',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐'},
#  {'tweet_id': '1442311011457925126',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar U mean Drishyam ......'},
#  {'tweet_id': '1442319089699995657',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar bhaiyya parody acct hai'},
#  {'tweet_id': '1442421478599938048',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar Sarcasm only bro🤣🤣'},
#  {'tweet_id': '1443412568123580424',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar He is just mimicking, c his profile'},
#  {'tweet_id': '1443982883098697770',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar Whooosh 💨'},
#  {'tweet_id': '1442198509831086082',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar whateveru say, zaidu is anti modi. whatever modi does, zaidu will make fun of it. zaidu will never say anything good about modi. be it for fun or whatever this twitter handle is for. :D lolz'},
#  {'tweet_id': '1442303266348417031',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar Atul bhaiya maja ley raha hai zaidu..🤪samajh nahi paye aap'},
#  {'tweet_id': '1442413379654602752',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks @TheNordicWar That’s the new Parliament building under construction. 😐@atulcanslim @TheZaiduLeaks @TheNordicWar The zero key has got stuck in your keyboard.\nAnyways illiterate PPL from religion of peace'},
#  {'tweet_id': '1442187738363535363',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Ek zero kam reh gayaa Zaidu Bhai. Fir se dekho.'},
#  {'tweet_id': '1442328768555601930',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Ek zero kam reh gayaa Zaidu Bhai. Fir se dekho.@GundaAsli @TheZaiduLeaks Madrasa mai etni he btye thee'},
#  {'tweet_id': '1442228987552407564',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Yaar padhne likhne ka riwaaz sach me hi khatam ho gaya hai kya Pakistan me itni toh duniya ki population nhi jitne tune zero lagaye hai.... Aur ye photo hata Pakitani sirf sucide bombing  kar k hi chand tak pahuche rocket udda k nahi'},
#  {'tweet_id': '1442249795620388864',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz"},
#  {'tweet_id': '1442315253409214465',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks True😂"},
#  {'tweet_id': '1442322886304227331',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Big Asshole😆😄"},
#  {'tweet_id': '1442325283789443079',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Only chutiyapa like you understood his sicr"},
#  {'tweet_id': '1442327912162607105',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Me too..."},
#  {'tweet_id': '1442337680365260809',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Naam bade aur darshan chote! Do you HEAR? Bade aye hain Sarcasm samjhaane!"},
#  {'tweet_id': '1442357148839677955',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Yeah... Me also 😂😂"},
#  {'tweet_id': '1442410258366746624',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Oh oh I don't care modi sahab,  hello Vikram bhaiya where u 😊"},
#  {'tweet_id': '1442410912917299201',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Not many"},
#  {'tweet_id': '1442421287318528003',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don\'t understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks U should stay away from "moodi" modi😂"kya pata kab danda kar de tumare"'},
#  {'tweet_id': '1442492066563493891',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks This is the caliber of Lawyers,writers,thinkers that follow such posts!"},
#  {'tweet_id': '1442623167651057664',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks I must agree. Most don't know the meaning of the word sarcasm."},
#  {'tweet_id': '1443128368447115264',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks True. Zaidu is indeed very funny."},
#  {'tweet_id': '1443950531509047297',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks S"},
#  {'tweet_id': '1442268551012773890',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Tu bada intelligent he chutiye... Basa sarcasm samjta he... Lodu"},
#  {'tweet_id': '1442268732705832961',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Converted muslim... Kalank he tu..."},
#  {'tweet_id': '1442321731062939649',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Left ka chela, communism ne hutiya bna diya hai tumhe😂😂"},
#  {'tweet_id': '1442342327024971776',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Abe lode tu hume sarcasm sikhayega"},
#  {'tweet_id': '1442349072455667714',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Karte karte khud majak bangaya"},
#  {'tweet_id': '1442434859331305478',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Sarcasm or plain dumb hatred...jaara difference seekh loh to achaa hoga demaag ke liye."},
#  {'tweet_id': '1442802486478209027',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Haan tatti paikhane mein hi milti hain soongho tum aur tumhara loudu sarcasm."},
#  {'tweet_id': '1442516514603556869',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Abe chutiye pahle hear aur here to thik se likh le ! Sale padosi ki aulad"},
#  {'tweet_id': '1443887064567537666',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks mental disorder ???? 😂"},
#  {'tweet_id': '1442365621144993800',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks I literally come hear to see how people react to your tweets, specifically those who don't understand the sarcasm. Lolz@Vikrama28562162 @TheZaiduLeaks Aabe bhosdike sarcasm wale gaand me bhar denge sarcasm maa bhi bolegi teri gand se guu niklega ki sarcasm.... Tum jaise chutiya to pata bhi nahi hoga ki is value ko pronounce kaise karenge.... Aaye bade sarcasm.... Desh drohi... 🤬"},
#  {'tweet_id': '1442263355247394819',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks This is the place where Pakistan govt. Will hide their face after New Zealand cancelled the match 🤣🤣🤣'},
#  {'tweet_id': '1442325931717058561',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks This is the place where Pakistan govt. Will hide their face after New Zealand cancelled the match 🤣🤣🤣@SoumickHazra1 @TheZaiduLeaks Nooo. But after selling Pakistan to China 😂'},
#  {'tweet_id': '1442337370808803337',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks This is the place where Pakistan govt. Will hide their face after New Zealand cancelled the match 🤣🤣🤣@SoumickHazra1 @TheZaiduLeaks 😆 😆 😆'},
#  {'tweet_id': '1442451243419324431',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks This is the place where Pakistan govt. Will hide their face after New Zealand cancelled the match 🤣🤣🤣@SoumickHazra1 @TheZaiduLeaks Rula diya na bechre Im-rona Khan ko.🤨😕😜 https://t.co/yqVHGy8Ckn'},
#  {'tweet_id': '1442288241743335425',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks People can write anything which is out of this world and malicious without fact check and nobody should question them ?'},
#  {'tweet_id': '1442290190249185280',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks People can write anything which is out of this world and malicious without fact check and nobody should question them ?@goel_harish @TheZaiduLeaks Call it sarcasm'},
#  {'tweet_id': '1442302446357729288',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Kuch bhi https://t.co/gRuIGWDbCx'},
#  {'tweet_id': '1442340569439633410',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Kuch bhi https://t.co/gRuIGWDbCx@HemantChutani @TheZaiduLeaks Bhai sarcasm tha iski purani tweets padh le pta chal jayega yeh kon hai'},
#  {'tweet_id': '1442305194922962944',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks हाथी चले बाजार, कुत्ते भौंके हज़ार... \nभौंकते रहो... जलनखोरों आतंक के पनाहगारों आतंकी कैम्प्स में गोला बारूद और भारत के खिलाफ नाग पालने में निवेश करने से बेहतर है यहां देश को कोई सौगात दी जाए... जलनखोर कहीं के...'},
#  {'tweet_id': '1442308707082072069',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Sahi baat hai, bohot badiya Jali hai Pakistan ki to kuch bhi matlab kuch bhi.'},
#  {'tweet_id': '1442341462151032834',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Sahi baat hai, bohot badiya Jali hai Pakistan ki to kuch bhi matlab kuch bhi.@kirankumar9800 @TheZaiduLeaks Sarcasm tha bhai iski purani tweets dekhle pta chal jayega kon hai phir follow krlio okk bhai'},
#  {'tweet_id': '1442311080991023104',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Pakistan numeral system countain 4 zero. After decades still weak in maths. Bright future ahead👍😂'},
#  {'tweet_id': '1442313025621356545',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe terrorist, jo tumne numeric likha hai kya tumko uske bare mein kuchh pata... \nMadarsa chaap hi rah jaoge jeevan bhar.\n#PakistanIsATerroristState'},
#  {'tweet_id': '1442341267115941894',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe terrorist, jo tumne numeric likha hai kya tumko uske bare mein kuchh pata... \nMadarsa chaap hi rah jaoge jeevan bhar.\n#PakistanIsATerroristState@MukeshK26881146 @TheZaiduLeaks Sarcasm tha bhai iski purani tweets dekhle pta chal jayega kon hai phir follow krlio okk bhai'},
#  {'tweet_id': '1442314522656587776',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Bhai tera phone khraab ho gya, apne aap 0 dab gya theek kra le jaake..\nDimaag to pehle se hi khraab hai'},
#  {'tweet_id': '1442317635681603585',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Haath mein achha phone ho,phone mein data poora ho aur dimag mein gobar ho to kya kuch nhi likha ja sakta.\nThode aur zero laga leta,khana nhi khaya tha kya achhe se😂'},
#  {'tweet_id': '1442335098867621892',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Haath mein achha phone ho,phone mein data poora ho aur dimag mein gobar ho to kya kuch nhi likha ja sakta.\nThode aur zero laga leta,khana nhi khaya tha kya achhe se😂@BhavyaMishra05 @TheZaiduLeaks Gobar nahi Bhai, in porkiyoon ke dimag mein suver ka gandagi hota hai. 😴'},
#  {'tweet_id': '1442318263812177923',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Zandu ho aur Zandu hi rahoge. Na jagah ka pata aur na ginti ka, bas kuch bolna tha toh bol diya'},
#  {'tweet_id': '1442341000240766980',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Zandu ho aur Zandu hi rahoge. Na jagah ka pata aur na ginti ka, bas kuch bolna tha toh bol diya@PoonamC2030 @TheZaiduLeaks Sarcasm tha bhai iski purani tweets dekhle pta chal jayega kon hai phir follow krlio okk bhai'},
#  {'tweet_id': '1442319494878142465',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks 2 ke aage kitne zero lagaye he jara gin bhi lete, ye total to pure india ke population ki bhi nahi he.\nHutiyapa band kar'},
#  {'tweet_id': '1442322282811068419',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Pakistan and pak people will never fail to entertain the world.🤣\nOnce go to Indian muslim and ask about pak,see what he will tell and ask about Modi see what he will tell💪and at last they will definitely say \nJAI HIND!!\nWe will never forget what happened to our kashmir pandits.'},
#  {'tweet_id': '1442350451693817859',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...'},
#  {'tweet_id': '1442408445861253128',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Madrason mein inhe padaya nahin jata. Mushkil se 0 to 10 Yaad Kiya hoga.'},
#  {'tweet_id': '1442409245199114256',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Epic sir'},
#  {'tweet_id': '1442707066938789890',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Gaddar kaum'},
#  {'tweet_id': '1442720287389147140',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Yeh chutita Pakija hain... What else you expect bro...'},
#  {'tweet_id': '1442806094384959492',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Lol it's a parody account guys relax"},
#  {'tweet_id': '1444713378849570819',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks 😂😂'},
#  {'tweet_id': '1442549089552371717',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Are place value system seekh e ki fursat kahan se aayegi. Madarso me sirf bomb banana aur aatankwad failana sikhaya jata hai. Vahi zeher faila raha hai. \nNothing new.'},
#  {'tweet_id': '1442695576538079236',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abe ghonchu .....kam se kam comma to sahi se laga leta .......place value system nhi sikhaya gaya kya maths mein...😂😂😂......sahi se number system to aata nhi hai...or inko kashmire chahiye.....😅😅...#PKMKB...@PrinceChaddha1 @TheZaiduLeaks Are kuch nahi aata sare kaam ulte karo padna likhna ulta\nPata nahi 🦇🦇🦇jaise ulte kaam kisne sikhaya hoga😂😂'},
#  {'tweet_id': '1442350869257678848',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Koun he ye log ..kanha se ate he ye....kitne honhar bachhe he ye...inko to math Olympiad dena chahiye. ...gajab kr diye bhaisahab...bas ek binati he apse ..ki apke mathematics k master sahab ka darsan mil jata to me dhanya ho jata...😅😅'},
#  {'tweet_id': '1442437041829023747',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Koun he ye log ..kanha se ate he ye....kitne honhar bachhe he ye...inko to math Olympiad dena chahiye. ...gajab kr diye bhaisahab...bas ek binati he apse ..ki apke mathematics k master sahab ka darsan mil jata to me dhanya ho jata...😅😅@rakesh945904 @TheZaiduLeaks 👍'},
#  {'tweet_id': '1442369199553273857',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz'},
#  {'tweet_id': '1442428350631329798',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks https://t.co/rxZxxwtldD\n\nIts fake bro check facts first and then write anything on public platform.. 😎😎'},
#  {'tweet_id': '1442430999623725060',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Santa?'},
#  {'tweet_id': '1442436047426650120',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks 🙏hamare modi jiii'},
#  {'tweet_id': '1442441571085873153',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Photoshopped. \n\nhttps://t.co/SlTCTnBBer'},
#  {'tweet_id': '1442448830063017996',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks And one has to see the reality, pain of the Indian Common Man due to Unemployment, Severe Inflation, Record Petrol Prices and Covid Disaster after a Foolish Demonitasion and a Faulty GST.'},
#  {'tweet_id': '1442455488843505665',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Bhakto ki aankho par kaali patti bandhi hui hai'},
#  {'tweet_id': '1442466318368731136',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Burnol time 😂 https://t.co/6fBxqv0iWM'},
#  {'tweet_id': '1442471903755522054',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Fake hai'},
#  {'tweet_id': '1442478932519899140',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 Sir, ye NYT ka tone kaise change ho gaya? Anti-anti-India se pro-India.'},
#  {'tweet_id': '1442479182332645389',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks You need to read spelling of September...lol, sorry लोल 😂😂'},
#  {'tweet_id': '1442488792166764544',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks NYT is most of the times AntiModi ...which unfortunately becomes AntiIndia...so it's surprising"},
#  {'tweet_id': '1442505697657163776',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks It's impossible for nyt to praise Modi and right wing"},
#  {'tweet_id': '1442514161838137345',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Brother se the spelling of September?'},
#  {'tweet_id': '1442525534265692162',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Is this real new paper?....then check the September spell....'},
#  {'tweet_id': '1442571943161614337',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Is he writing " what you want to put in" in the visitors\nBook.'},
#  {'tweet_id': '1442573261716353025',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks This post fake but our pm above this type of fame and name.'},
#  {'tweet_id': '1442593355028860929',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks Bro its fake 🤪🤪'},
#  {'tweet_id': '1442771763268505601',
#   'text': "Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks You need to read this also https://t.co/GLoTSYlgpz@Shailes57839662 @TheZaiduLeaks See the fake dates....26 'Setpember'.....😀😀😀😀"},
#  {'tweet_id': '1442385149430145025',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abbe Tum logo ko immu uncle ne cocaine zyada dedi kya...jo ayesi bakwas kar rahe ho jhundistan ke paltu kawwe....chand ka DP laga rakha hai...sirf tumhare jhande me hai....chand tak pohach nahi sakte jhandistan...ja ke le le....immu uncle se thodasa cocaine....'},
#  {'tweet_id': '1442554945316683788',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks Abbe Tum logo ko immu uncle ne cocaine zyada dedi kya...jo ayesi bakwas kar rahe ho jhundistan ke paltu kawwe....chand ka DP laga rakha hai...sirf tumhare jhande me hai....chand tak pohach nahi sakte jhandistan...ja ke le le....immu uncle se thodasa cocaine....@TheZaiduLeaks Hamare yaha bhi palahua hai ek....jiddu...nahi suddhu\n.. Are nahi Siddhu....jiski sidhi kabhi hoti hi nahi...de talli..phtak.....usne bohot badaa liya hai immu uncle ka....mu me...isliye Kapil Sharma show se bahar hogaya'},
#  {'tweet_id': '1533444368690032641',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩"},
#  {'tweet_id': '1533449166197760000',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad"},
#  {'tweet_id': '1533454104042913792',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 Conclusion.....\nTel khatam khel khatam"},
#  {'tweet_id': '1533464105683718144',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Came to say exact same line. Kudos"},
#  {'tweet_id': '1533464105683718144',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Came to say exact same line. Kudos"},
#  {'tweet_id': '1533492572630286336',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Haan isiliye abb modi  ne 1 mahine m russ se 100× oil important krra h 😌"},
#  {'tweet_id': '1533508102942650368',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 I'm not using #Arab  oil I'm using Russian oil.....😂😂🤣"},
#  {'tweet_id': '1533487892676616192',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom यहां बात उन गद्दार जिहादियों की हो रही है जो खाते इस देश का हैं और फिर देश को ही दगा देते हैं। इस देश के गद्दार जिहादियों का बहिष्कार जरूरी है।"},
#  {'tweet_id': '1533451514802343936',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Ham fuel ke jagah CNG use karenge aur pollution ko kam karenge\nWaise bhi jis din tumhara tel khtm uss din tumhara khel khtm"},
#  {'tweet_id': '1533509074037481474',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Isiliye abb India ne 🇷🇺 Russia se petrol lena start karr diya"},
#  {'tweet_id': '1533511761466339329',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Gobar se aag jala lenge our go mutro se gari chala lenge no problem bro  🤣"},
#  {'tweet_id': '1533553873620639744',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Kya jawab diye ji...😂😂😂dil kush kardiye samu"},
#  {'tweet_id': '1533692757620903937',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Tel Geography ke wajah se hai unhone koi mehnat nhi ki uske liye. Kal agr wo hindu nation bhi ban jaaye to bhi tel nikalta hi rahega. Unki charbi sirf tel ke wajah se hai jaise hi tel khatm unki value khatam aur tel 30,40 saal me khatam hoga. Tab tak duniya ko islam se ladna hoga"},
#  {'tweet_id': '1533760472687820800',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Y don't u start first by not using fuel. All the best 🌝 #Stopinsulting_ProphetMuhammad@sum_rin_89 @ICPMhariom Pupet Mohammad 🤣😂 https://t.co/r0fEZEfyq4"},
#  {'tweet_id': '1533454519363072000',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Brother it's nothing of your business.u looking young from ur dp start building ur career focus on ur goal.if not u will regret later on..😊😊"},
#  {'tweet_id': '1533521424476143616',
#   'text': "#ShameOnBJP #IStandWithNupurSharma\nDear Hindus,\nIf you are upset and want to support नूपुर शर्मा  then let's fight for it.\n *Boycott muslims economically\n*Sue and expose everyone who mocked Hindu Deities.\n*Assure no muslim shops in hindu pilgrimage areas\nहर हर महादेव 🚩🚩@ICPMhariom Brother it's nothing of your business.u looking young from ur dp start building ur career focus on ur goal.if not u will regret later on..😊😊@imshuaibsdk @ICPMhariom He is already in his job and he achieves more heights 😂"},
#  {'tweet_id': '1533539206890414080',
# ...
#  {'tweet_id': '1480598997265891328',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV @pikaso_me screenshot this"},
#  {'tweet_id': '1480599030354698240',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV @pikaso_me screenshot this@sundarrajachola @SadhguruJV Here's your screenshot. For more options (like dark mode), please visit https://t.co/6fIpjtsiEr. https://t.co/sI5Ykty8MT"},
#  {'tweet_id': '1480752178885115906',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV If someone is good at a particular sport that doesn't give him a right to spread lies.\n@NSaina has brought medals for India in sports category as a sports women.\nBut now she has joined politics.\nShe will certainly be criticised for her political Statement."},
#  {'tweet_id': '1480789315697274880',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV If someone is good at a particular sport that doesn't give him a right to spread lies.\n@NSaina has brought medals for India in sports category as a sports women.\nBut now she has joined politics.\nShe will certainly be criticised for her political Statement.@manoj4justice @SadhguruJV @NSaina But you can’t demean someone like that. Use proper words to raise your voice"},
#  {'tweet_id': '1480800626615353344',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV If someone is good at a particular sport that doesn't give him a right to spread lies.\n@NSaina has brought medals for India in sports category as a sports women.\nBut now she has joined politics.\nShe will certainly be criticised for her political Statement.@manoj4justice @SadhguruJV @NSaina First know what criticism means and how to do it in a civilized society."},
#  {'tweet_id': '1481080546214223874',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV If someone is good at a particular sport that doesn't give him a right to spread lies.\n@NSaina has brought medals for India in sports category as a sports women.\nBut now she has joined politics.\nShe will certainly be criticised for her political Statement.@manoj4justice @SadhguruJV @NSaina You are saying a sports person should talk about sports ...then why a actor should be talking about politics and also criticizing her on sports ?? 🤭. Please be clear you are trapping yourself. And what leverage does Siddharth has over a sports person ? You are plain dumb😆"},
#  {'tweet_id': '1480518745407823878',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Elephant 🐘 killer"},
#  {'tweet_id': '1480519161570676736',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Elephant 🐘 killer@travellover1987 @SadhguruJV but u r a vermin😂😂"},
#  {'tweet_id': '1480519719295672325',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Elephant 🐘 killer@travellover1987 @SadhguruJV Prove it , LOW IQ"},
#  {'tweet_id': '1480519796051505153',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦"},
#  {'tweet_id': '1480525148323078144',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV 636 following 6 followers. Jis din 10 ho jaye na us din btaunga teko chutiye 😂🤣 https://t.co/pBzfYHTCmc"},
#  {'tweet_id': '1480525648443555840',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV Tell this to that disgusting actor who made such disgusting comment about our nation's pride @NSaina .\nCheap followers of cheap actors!"},
#  {'tweet_id': '1480525754056151043',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV Bsdk tujhse varify karke post kare kaha se atein aise single chromosome chutiye..."},
#  {'tweet_id': '1480536883859914758',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV who are you??"},
#  {'tweet_id': '1480541413980839937',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV Democracy is for everyone.. it's your ignorance that you can't understand the basic ethics of this country🙄"},
#  {'tweet_id': '1480570633247469576',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV Why do Churches and Jamath even advice who to vote for?"},
#  {'tweet_id': '1480580547181043712',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 Hv u not seen gurus of the past fighting invaders, rising to save nation, guide Kings, teach various arts, stirr humanness when a person lacks it, harmony etc.who are u to fix a template.u do ur work.let him do his.idiots like u want others to behave the way u want..publicity p.g"},
#  {'tweet_id': '1480731400638664704',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV Are you #Naughty meaning Haram***** \nIf not\n just mind business"},
#  {'tweet_id': '1480611369435099137',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV why, has the govt or even u exempted  him of anything...he has every right as any other citizen has...moron"},
#  {'tweet_id': '1480747133456162816',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Why are you commenting on everything being a so called spiritual guru 🤦@karna1394 @SadhguruJV Can you give such comments for your mother and sister?If yes,then you are a disgrace on earth.Dub Maro."},
#  {'tweet_id': '1480524724803231744',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Saina is badminton Star not a political pundit.She should avoid political insinuation"},
#  {'tweet_id': '1480613228283514882',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Saina is badminton Star not a political pundit.She should avoid political insinuation@wisechirping @SadhguruJV Karwali insult. Maza aaya?"},
#  {'tweet_id': '1480647634448576512',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Saina is badminton Star not a political pundit.She should avoid political insinuation@wisechirping @SadhguruJV I don't know what why Muslim defending @Actor_Siddharth is it whatever happens we always blame BJP"},
#  {'tweet_id': '1480739489341493255',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Saina is badminton Star not a political pundit.She should avoid political insinuation@wisechirping @SadhguruJV when a non entity like you can talk politics why cant a badminton star. shut up"},
#  {'tweet_id': '1480526473178099719',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?"},
#  {'tweet_id': '1480530245853745154',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV This is about basic values and decency. An abusive indecent person can't grow spiritually. But then you hypocrites will defend his disgusting behaviour. Here's another of his abusive tweet. https://t.co/2CY9qgRwBJ"},
#  {'tweet_id': '1480538591973416963',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Both so what when someone is abusing an esteemed woman athlete you are interested in those speaking for her shows who you are psycho"},
#  {'tweet_id': '1480566572758536192',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Why when Christian and Muslim religious leaders uter nonsence why can’t a hindu guru be a a citizen"},
#  {'tweet_id': '1480578557185196034',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV I did not knew our Constitution doesn't give any right to speak to Spiritual Leaders like @SadhguruJV that too for a National asset like @SainaNehwal😂😂😂😂"},
#  {'tweet_id': '1480579935710420995',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV I really pity the soul inside of u, so you will now fix what a Guru shoud do or not do! , remember he is also a human being like u though it's doubtful if u have evolved to be  human being or still a reptile speaks from inside of you. Atleast try, being Human is not far away👍."},
#  {'tweet_id': '1480580318918635520',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Tum kya ho kutte"},
#  {'tweet_id': '1480587853046304770',
#   'text': '#SainaNehwal is Nation\'s pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Priya your bio says " yoga is my drug 😂" But your retweets points towards Namaz only😂'},
#  {'tweet_id': '1480602118494953472',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV What an uninformed person you are.\n\nWas Vishwamitra a political Brahma Rishi or a spiritual maharishi?"},
#  {'tweet_id': '1480607051621355521',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Yes only politician can speak about a politician.. ab ye bta tu kon se politician ki aulad hai jo tu bhokk rha hai yhaa aake"},
#  {'tweet_id': '1480607379792154624',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Tum kon ho putri jo bhokk rhi ho tum kon hoti ho kisi ko bolne vali ki vo bole ki na bole tumko kisne ye rights dia"},
#  {'tweet_id': '1480742887306326019',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV You have absolute no clue of spirituality, do you!?"},
#  {'tweet_id': '1480798507980103680',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Someone criticises a mugger for a bad comment, you take sides of the mugger are you born in an animal kingdom or born of one. Ass perhaps"},
#  {'tweet_id': '1481113899584077828',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV Don't you think he has constitutional rights to speak? Get a life Priya. Whole world is waking up and supporting women. He is just compassionate enough to support a woman being abused. In a western country Siddharth will be face defamation case and will be banned from Twitter."},
#  {'tweet_id': '1480566189923438593',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod @SadhguruJV He always he’s a Indian then anything else you are too stupid to understand such things"},
#  {'tweet_id': '1480791035328573442',
#   'text': "#SainaNehwal is Nation's pride. Most distasteful and disgusting, where are we taking public discourse… -Sg@SadhguruJV Is that anything spiritual about it? Yoga guru or political guru?@Pitysoulgod None of your business. Keep shut 🤐. That bastard is an actor can you ask him just to act you a**h*le"},
#  {'tweet_id': '1442176510224261120',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K'},
#  {'tweet_id': '1442176690235461647',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks 😂😂 मान जा !!'},
#  {'tweet_id': '1442341201479233543',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks 😂😂 मान जा !!@KamalKesari1 @TheZaiduLeaks Sarcasm tha bhai iski purani tweets dekhle pta chal jayega kon hai phir follow krlio okk bhai'},
#  {'tweet_id': '1442176841322618880',
#   'text': 'Darinder Moodi showing mass grave where he buried 200,000,0000,0000 Muslims in 2002 Gujarat Riots. https://t.co/VjASMBEe0K@TheZaiduLeaks No this is new grievyard in making..😂😂😂😂'},
#  ...]

# %%
test_df = pd.DataFrame(test_tweetid_data, columns = test_tweetid_data[0].keys(), index = None)

# %%
test_df.head()
# Out:
#               tweet_id                                               text
# 0  1442176510224261120  Darinder Moodi showing mass grave where he bur...
# 1  1442176690235461647  Darinder Moodi showing mass grave where he bur...
# 2  1442341201479233543  Darinder Moodi showing mass grave where he bur...
# 3  1442176841322618880  Darinder Moodi showing mass grave where he bur...
# 4  1442177683899568133  Darinder Moodi showing mass grave where he bur...

# %%
test_df.shape
# Out:
# (2988, 2)

# %%
test_tweets = test_df.text
tweet_ids = test_df.tweet_id

# %%
cleaned_test = [clean_tweet(tweet) for tweet in test_tweets]

# %%
X_test = vectorizer.transform(cleaned_test)
X_test = X_test.todense()

# %%
submission_prediction = Classifier.predict(X_test)
submission = {'id': tweet_ids, 'label':submission_prediction}
submission = pd.DataFrame(submission)

# %%
submission.shape
# Out:
# (2988, 2)

# %%
submission.head(20)
# Out:
#                      id  label
# 0   1442176510224261120      0
# 1   1442176690235461647      0
# 2   1442341201479233543      1
# 3   1442176841322618880      0
# 4   1442177683899568133      0
# 5   1442198857278844934      0
# 6   1442183360713953284      0
# 7   1442177876720189440      1
# 8   1442206853589467137      1
# 9   1442269798704967681      1
# 10  1442320695115927557      1
# 11  1442379323558617094      1
# 12  1442667363774517250      1
# 13  1442178416002801670      0
# 14  1442489267863769088      0
# 15  1442178482872586244      0
# 16  1442182525309227013      1
# 17  1442178618063347714      0
# 18  1442180105116078085      0
# 19  1442320048069115904      1

# %%
submission.to_csv('submission.csv', index = False)
